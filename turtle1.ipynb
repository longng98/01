# %%
def VeHinhVuongCachSo1():
    #khoi tao thu vien turtle
    import turtle
    t = turtle.Turtle()
    for i in range(4):
        #di thang
        t.forward(100)
        #quay phai 90 do
        t.right(90)
    turtle.exitonclick()
    if __name__ == "__main__":
        VeHinhVuongCachSo1()
VeHinhVuongCachSo1()
turtle.done()

# %%
import turtle
t = turtle.Turtle()

#to mau hinh chu nhat
t.pensize(3)
t.pencolor('blue')
t.begin_fill()
for i in range(2):
    t.forward(200)
    t.right(90)
    t.forward(100)
    t.right(90)
t.end_fill()
turtle.done()

# %%
import turtle
t = turtle.Turtle()

#ve hinh tron mau vang vien xanh

t.pensize(3)
t.pencolor('blue')
t.fillcolor('yellow')
t.begin_fill()
t.circle(100)
t.end_fill()
turtle.done()

# %%
import turtle
t = turtle.Turtle()

#ve va to mau ngoi sao

turtle.bgcolor('red')
t.pensize(3)
t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
for i in range(5):
    t.forward(50)
    t.right(144)
t.end_fill()
turtle.done()

# %%
#Ve ngoi nha mo uoc
#__________________
#ve co
import turtle
g = turtle.Turtle()
g.fillcolor('green')
g.pensize(3)
g.speed(10)
g.penup()
g.rt(90)
g.fd(75)
g.lt(90)
g.pendown()
g.fd(-400)
g.begin_fill()
for i in range(2):
    g.fd(800)
    g.rt(90)
    g.fd(300)
    g.rt(90)
g.end_fill()
import turtle
import math
t = turtle.Turtle()
#mau nen xanh cyan
turtle.bgcolor('cyan')
#ve tuong nha 1
t.pensize(3)
t.speed(10)
t.fillcolor('yellow')
t.begin_fill()
a = 200
b = 100
t.rt(90)
t.fd(a)
t.rt(60)
t.fd(b)
t.rt(120)
t.fd(a)
t.rt(60)
t.fd(b)
t.end_fill()
#ve cua so 1
t.penup()
t.goto(-b/5,-a/5)
t.pendown()
t.fillcolor('brown')
t.begin_fill()
t.fd(-60)
t.rt(120)
t.fd(60)
t.lt(120)
t.fd(60)
t.lt(60)
t.fd(60)
t.end_fill()
#ve tuong nha 2
t.penup()
t.goto(-math.sqrt(pow(b,2)-pow(b/2,2)),-a-b/2)
t.pendown()
t.fillcolor('blue')
t.begin_fill()
t.lt(90)
for i in range(3):
    t.fd(a)
    t.rt(90)
t.end_fill()
#ve cua chinh
t.fillcolor('goldenrod')
t.fd(a)
t.rt(90)
t.fd(a/3)
t.begin_fill()
t.rt(90)
for i in range(2):
    t.fd(a/2)
    t.lt(90)
    t.fd(a/3)
    t.lt(90)
t.end_fill()
#ve mai nha truoc
import turtle
m = turtle.Turtle()
m.pensize(3)
m.speed(10)
m.fillcolor('magenta')
m.rt(150)
m.fd(b)
m.rt(75)
m.begin_fill()
for i in range(2):
    m.fd(math.sqrt(2*pow(b,2)))
    m.lt(90)
m.end_fill()
#ve mai nha sau
m.fillcolor('orange')
m.lt(90)
m.fd(math.sqrt(2*pow(b,2)))
m.rt(15)
m.begin_fill()
m.fd(b)
m.rt(75)
m.fd(math.sqrt(2*pow(b,2)))
m.rt(105)
m.fd(b)
m.end_fill()
#ve cay
import turtle
c = turtle.Turtle()
c.speed(10)
c.fillcolor('brown4')
c.pensize(3)
c.penup()
c.goto(100,-100)
c.pendown()
#than cay
c.begin_fill()
for i in range(2):
    c.fd(20)
    c.lt(90)
    c.fd(b)
    c.lt(90)
c.end_fill()
#ve la cay
c.fillcolor('green3')
d = math.sqrt(2*pow(50,2))
c.penup()
c.goto(60,-50)
c.pendown()
for i in range(3):
    c.penup()
    c.lt(90)
    c.fd(50)
    c.pendown()
    c.begin_fill()
    c.rt(45)
    c.fd(d)
    c.rt(90)
    c.fd(d)
    c.rt(135)
    c.fd(b)
    c.rt(180)
    c.end_fill()
#ve may
import turtle
may = turtle.Turtle()
may.pensize(3)
may.speed(10)
may.fillcolor('white')
may.pencolor('white')
may.penup()
may.goto(-200,200)
may.pendown()
may.begin_fill()
may.circle(10)
may.end_fill()
may.penup()
may.goto(-190,210)
may.pendown()
may.begin_fill()
may.circle(15)
may.end_fill()
may.penup()
may.goto(-170,200)
may.pendown()
may.begin_fill()
may.circle(20)
may.end_fill()
may.penup()
may.goto(-190,190)
may.pendown()
may.begin_fill()
may.circle(8)
may.end_fill()
may.penup()
may.goto(-180,190)
may.pendown()
may.begin_fill()
may.circle(10)
may.end_fill()
#ve mat troi
import turtle
s = turtle.Turtle()
s.speed(10)
s.pencolor('yellow')
s.fillcolor('yellow')
s.penup()
s.goto(200,200)
s.pendown()
s.begin_fill()
s.circle(40)
s.end_fill()
turtle.done()
